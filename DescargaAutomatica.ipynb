# %%
import pandas as pd
url = 'https://educacion.gob.ec/wp-content/uploads/downloads/2022/02/2_MINEDUC_RegistrosAdministrativos_2016-2017_Inicio.csv'
#data = pd.read_csv(url)
data = pd.read_csv(url, index_col=0,sep=';', encoding='latin-1')
data.head()

filename = "/Users/Ale/PROYECTOS/mineduc"

#exportamos
data.to_csv(filename + ".csv")
# Out:
#                     Zona  Cod_Provincia  Cod_Canton  Cod_Parroquia  \
# ï»¿Periodo
# 2016-2017 Inicio  ZONA 6              1         101          10151
# 2016-2017 Inicio  ZONA 6              1         101          10153
# 2016-2017 Inicio  ZONA 6              1         101          10161
# 2016-2017 Inicio  ZONA 6              1         101          10161
# 2016-2017 Inicio  ZONA 6              1         101          10161
#
#                  Codigo_Institucion Escolarizacion      Tipo_Educacion  \
# ï»¿Periodo
# 2016-2017 Inicio           01B00020   Escolarizada  EducaciÃ³n Regular
# 2016-2017 Inicio           01B00021   Escolarizada  EducaciÃ³n Regular
# 2016-2017 Inicio           01B00027   Escolarizada  EducaciÃ³n Regular
# 2016-2017 Inicio           01B00028   Escolarizada  EducaciÃ³n Regular
# 2016-2017 Inicio           01B00029   Escolarizada  EducaciÃ³n Regular
#
#                      Nivel_Educacion Sostenimiento       Area  ...  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17401 entries, 2016-2017 Inicio to 2016-2017 Inicio
# Data columns (total 69 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Zona                                 17401 non-null  object
#  1   Cod_Provincia                        17401 non-null  int64
#  2   Cod_Canton                           17401 non-null  int64
#  3   Cod_Parroquia                        17401 non-null  int64
#  4   Codigo_Institucion                   17401 non-null  object
#  5   Escolarizacion                       17401 non-null  object
#  6   Tipo_Educacion                       17401 non-null  object
#  7   Nivel_Educacion                      17401 non-null  object
#  8   Sostenimiento                        17401 non-null  object
#  9   Area                                 17401 non-null  object
# ...

# %%
filename = "/Users/Ale/PROYECTOS/mineduc"

#exportamos
data.to_csv(filename + ".csv")
